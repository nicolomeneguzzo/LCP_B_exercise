# %% [markdown]
# # DNN: analysis with Keras of 2D data

# %% [markdown]
# # Keras Tuner
# check https://keras.io/keras_tuner/getting_started/ or just pip install keras-tuner -q
#
# install tensorflow

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout

import matplotlib as mpl
import matplotlib.pyplot as plt
# default font
plt.rcParams['font.size'] = 13

from sklearn.preprocessing import StandardScaler

# %run useful.py

# training/validation/test fractions
perc_train = 0.7
perc_valid = 0.15
perc_test = 0.15
#  check it sums to 1 
assert abs(perc_train + perc_valid + perc_test - 1.0) < 1e-12

# %% [markdown]
# ## Read data

# %%
# Keras works with numpy arrays: just use them from the start

TYPE=4
# number of features per sample
L=8
# span of each component
B=10
x = np.loadtxt(filename("data",L,TYPE), delimiter=' ')
y = np.loadtxt(filename("labels",L,TYPE), delimiter=' ')
y = y.astype("int")
print(x.shape)
N = len(x)


# dim. of a sample
L = len(x[0])
print(L)

for i in range(5):
    print(x[i],y[i])

N_train = int(perc_train * N)
N_valid = int(perc_valid * N)
N_test = N - N_train - N_valid
print(f'data: {N}\ntrain: {N_train}\nvalid: {N_valid}\ntest: {N_test}')

plot_data(x,y)
# Out:
# (12000, 8)
# 8
# [1.83918812 2.04560279 5.67725029 5.95544703 9.6451452  6.53177097
#  7.48906638 6.53569871] 0
# [7.47714809 9.61306736 0.08388298 1.06444377 2.98703714 6.56411183
#  8.09812553 8.72175914] 0
# [9.64647597 7.23685347 6.42475328 7.17453621 4.67599007 3.25584678
#  4.39644606 7.29689083] 0
# [9.94014586 6.76873712 7.90822518 1.70914258 0.26849276 8.00370244
#  9.03722538 0.2467621 ] 0
# [4.91747318 5.26255167 5.9636601  0.51957545 8.95089528 7.2826618
#  8.18350011 5.00222753] 1
# data: 12000
# train: 8400
# valid: 1800
# test: 1800

# %% [markdown]
# ## Split data and standardize (fit on train only)

# %%
def Standardize(x,m,s):
    """
    rescale each component using its mean and standard deviation
    x: data points (numpy array)
    m: mean values (numpy array)
    s: standard deviations (numpy array)
    return: rescaled data points (numpy array)
    """
    N = len(x)
    # assuming len(m)=len(s)=len(x[0])
    mm,ss = np.tile(m,(N,1)), np.tile(s,(N,1))
    return (x-mm)/ss

# split data into train/validation/test sets and check 
(x_train, y_train) = (x[0:N_train],y[0:N_train])
(x_valid, y_valid) = (x[N_train:N_train+N_valid],y[N_train:N_train+N_valid])
(x_test, y_test) = (x[N_train+N_valid:],y[N_train+N_valid:])
print("Train:",len(x_train),"\t Validation:",len(x_valid),"\t Test:",len(x_test))


x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)
#print("train stats before rescaling:\nmean value=", x_train_mean, "\nstd. dev.=", x_train_std)

x_valid_mean = np.mean(x_valid, axis=0)
x_valid_std = np.std(x_valid, axis=0)
#print("validation stats before rescaling:\nmean value=", x_valid_mean, "\nstd. dev.=", x_valid_std)

x_test_mean = np.mean(x_test, axis=0)
x_test_std = np.std(x_test, axis=0)
#print("test stats before rescaling:\nmean value=", x_test_mean, "\nstd. dev.=", x_test_std)

x_train = Standardize(x_train, x_train_mean, x_train_std)
x_valid = Standardize(x_valid, x_valid_mean, x_valid_std)
x_test = Standardize(x_test, x_test_mean, x_test_std)
print("after rescaling (train):\nmean value=", x_train.mean(axis=0), "\nstd. dev.=", x_train.std(axis=0))
# Out:
# Train: 8400 	 Validation: 1800 	 Test: 1800
# after rescaling (train):
# mean value= [ 9.17572896e-16  1.18834043e-14 -1.95478554e-15 -3.53337069e-15
#  -6.42594443e-15 -2.40365928e-15 -2.88332932e-15 -8.27623684e-15]
# std. dev.= [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Define the model with Keras / Tensorflow

# %%
# reproducibility (?)
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

# We use case 1
CASE=1

if CASE==1:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
# as case 1 but one layer shorter
if CASE==2:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(40,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
#deeper
if CASE==3:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
    
print(model.summary())
# Out:
# /home/nicol/miniconda3/envs/lcpenv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773064821.858279   26616 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2141 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,113 (4.35 KB)
#  Trainable params: 1,113 (4.35 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Optimization method and cost function

# %%
model.compile(loss='binary_crossentropy',
              optimizer='RMSprop',
              #optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
fit = model.fit(x_train, y_train,
               epochs = nepoch, batch_size = 50,
               validation_data=(x_valid,y_valid),
               verbose=2)
# Out:
# Epoch 1/200
# 2026-03-09 15:06:49.241938: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f8bc00092e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-09 15:06:49.241956: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2026-03-09 15:06:49.288850: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-09 15:06:49.454229: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91700
# I0000 00:00:1773065212.052867   29510 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 168/168 - 5s - 27ms/step - accuracy: 0.5060 - loss: 0.6948 - val_accuracy: 0.5028 - val_loss: 0.6929
# Epoch 2/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5129 - loss: 0.6915 - val_accuracy: 0.5100 - val_loss: 0.6923
# Epoch 3/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5218 - loss: 0.6899 - val_accuracy: 0.5161 - val_loss: 0.6905
# Epoch 4/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5235 - loss: 0.6889 - val_accuracy: 0.5061 - val_loss: 0.6886
# Epoch 5/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5264 - loss: 0.6869 - val_accuracy: 0.5028 - val_loss: 0.6870
# Epoch 6/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5270 - loss: 0.6869 - val_accuracy: 0.5083 - val_loss: 0.6853
# Epoch 7/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5292 - loss: 0.6852 - val_accuracy: 0.5178 - val_loss: 0.6845
# Epoch 8/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5280 - loss: 0.6861 - val_accuracy: 0.5139 - val_loss: 0.6839
# Epoch 9/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5360 - loss: 0.6845 - val_accuracy: 0.5178 - val_loss: 0.6835
# Epoch 10/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5329 - loss: 0.6845 - val_accuracy: 0.5200 - val_loss: 0.6836
# Epoch 11/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5405 - loss: 0.6835 - val_accuracy: 0.5217 - val_loss: 0.6832
# Epoch 12/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5374 - loss: 0.6847 - val_accuracy: 0.5139 - val_loss: 0.6838
# Epoch 13/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5390 - loss: 0.6834 - val_accuracy: 0.5139 - val_loss: 0.6830
# Epoch 14/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5369 - loss: 0.6831 - val_accuracy: 0.5100 - val_loss: 0.6830
# Epoch 15/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5356 - loss: 0.6843 - val_accuracy: 0.5178 - val_loss: 0.6822
# Epoch 16/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5388 - loss: 0.6839 - val_accuracy: 0.5200 - val_loss: 0.6823
# Epoch 17/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5362 - loss: 0.6830 - val_accuracy: 0.5172 - val_loss: 0.6821
# Epoch 18/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5349 - loss: 0.6827 - val_accuracy: 0.5156 - val_loss: 0.6822
# Epoch 19/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5401 - loss: 0.6827 - val_accuracy: 0.5139 - val_loss: 0.6817
# Epoch 20/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5420 - loss: 0.6812 - val_accuracy: 0.5183 - val_loss: 0.6820
# Epoch 21/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5440 - loss: 0.6822 - val_accuracy: 0.5156 - val_loss: 0.6822
# Epoch 22/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5442 - loss: 0.6824 - val_accuracy: 0.5150 - val_loss: 0.6823
# Epoch 23/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5474 - loss: 0.6815 - val_accuracy: 0.5250 - val_loss: 0.6810
# Epoch 24/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5393 - loss: 0.6813 - val_accuracy: 0.5144 - val_loss: 0.6810
# Epoch 25/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5436 - loss: 0.6812 - val_accuracy: 0.5117 - val_loss: 0.6810
# Epoch 26/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5464 - loss: 0.6798 - val_accuracy: 0.5161 - val_loss: 0.6812
# Epoch 27/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5385 - loss: 0.6807 - val_accuracy: 0.5100 - val_loss: 0.6807
# Epoch 28/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5508 - loss: 0.6786 - val_accuracy: 0.5200 - val_loss: 0.6815
# Epoch 29/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5371 - loss: 0.6811 - val_accuracy: 0.5211 - val_loss: 0.6812
# Epoch 30/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5444 - loss: 0.6795 - val_accuracy: 0.5156 - val_loss: 0.6805
# Epoch 31/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5467 - loss: 0.6791 - val_accuracy: 0.5189 - val_loss: 0.6807
# Epoch 32/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5523 - loss: 0.6779 - val_accuracy: 0.5117 - val_loss: 0.6812
# Epoch 33/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5454 - loss: 0.6780 - val_accuracy: 0.5194 - val_loss: 0.6803
# Epoch 34/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5480 - loss: 0.6775 - val_accuracy: 0.5261 - val_loss: 0.6788
# Epoch 35/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5410 - loss: 0.6774 - val_accuracy: 0.5261 - val_loss: 0.6786
# Epoch 36/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5387 - loss: 0.6758 - val_accuracy: 0.5339 - val_loss: 0.6775
# Epoch 37/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5510 - loss: 0.6762 - val_accuracy: 0.5350 - val_loss: 0.6773
# Epoch 38/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5439 - loss: 0.6762 - val_accuracy: 0.5406 - val_loss: 0.6764
# Epoch 39/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5464 - loss: 0.6759 - val_accuracy: 0.5394 - val_loss: 0.6763
# Epoch 40/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5481 - loss: 0.6738 - val_accuracy: 0.5417 - val_loss: 0.6758
# Epoch 41/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5411 - loss: 0.6744 - val_accuracy: 0.5356 - val_loss: 0.6750
# Epoch 42/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5563 - loss: 0.6740 - val_accuracy: 0.5422 - val_loss: 0.6747
# Epoch 43/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5469 - loss: 0.6747 - val_accuracy: 0.5500 - val_loss: 0.6737
# Epoch 44/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5511 - loss: 0.6743 - val_accuracy: 0.5389 - val_loss: 0.6733
# Epoch 45/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5549 - loss: 0.6732 - val_accuracy: 0.5367 - val_loss: 0.6730
# Epoch 46/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5532 - loss: 0.6714 - val_accuracy: 0.5483 - val_loss: 0.6720
# Epoch 47/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5545 - loss: 0.6710 - val_accuracy: 0.5478 - val_loss: 0.6716
# Epoch 48/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5640 - loss: 0.6704 - val_accuracy: 0.5533 - val_loss: 0.6710
# Epoch 49/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5527 - loss: 0.6718 - val_accuracy: 0.5411 - val_loss: 0.6723
# Epoch 50/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5598 - loss: 0.6700 - val_accuracy: 0.5467 - val_loss: 0.6713
# Epoch 51/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5577 - loss: 0.6689 - val_accuracy: 0.5494 - val_loss: 0.6700
# Epoch 52/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5583 - loss: 0.6705 - val_accuracy: 0.5428 - val_loss: 0.6696
# Epoch 53/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5596 - loss: 0.6688 - val_accuracy: 0.5478 - val_loss: 0.6689
# Epoch 54/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5560 - loss: 0.6677 - val_accuracy: 0.5444 - val_loss: 0.6686
# Epoch 55/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5557 - loss: 0.6702 - val_accuracy: 0.5472 - val_loss: 0.6681
# Epoch 56/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5575 - loss: 0.6674 - val_accuracy: 0.5472 - val_loss: 0.6685
# Epoch 57/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5690 - loss: 0.6654 - val_accuracy: 0.5506 - val_loss: 0.6678
# Epoch 58/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5606 - loss: 0.6665 - val_accuracy: 0.5472 - val_loss: 0.6673
# Epoch 59/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5592 - loss: 0.6663 - val_accuracy: 0.5472 - val_loss: 0.6665
# Epoch 60/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5614 - loss: 0.6640 - val_accuracy: 0.5461 - val_loss: 0.6661
# Epoch 61/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5670 - loss: 0.6637 - val_accuracy: 0.5594 - val_loss: 0.6633
# Epoch 62/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5738 - loss: 0.6592 - val_accuracy: 0.5717 - val_loss: 0.6620
# Epoch 63/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5726 - loss: 0.6606 - val_accuracy: 0.5756 - val_loss: 0.6590
# Epoch 64/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5814 - loss: 0.6580 - val_accuracy: 0.5811 - val_loss: 0.6586
# Epoch 65/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5764 - loss: 0.6585 - val_accuracy: 0.5822 - val_loss: 0.6583
# Epoch 66/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5762 - loss: 0.6568 - val_accuracy: 0.5794 - val_loss: 0.6583
# Epoch 67/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5836 - loss: 0.6555 - val_accuracy: 0.5867 - val_loss: 0.6556
# Epoch 68/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5796 - loss: 0.6540 - val_accuracy: 0.5789 - val_loss: 0.6557
# Epoch 69/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5830 - loss: 0.6501 - val_accuracy: 0.5906 - val_loss: 0.6525
# Epoch 70/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5800 - loss: 0.6526 - val_accuracy: 0.5839 - val_loss: 0.6533
# Epoch 71/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5844 - loss: 0.6515 - val_accuracy: 0.5872 - val_loss: 0.6510
# Epoch 72/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5840 - loss: 0.6498 - val_accuracy: 0.5889 - val_loss: 0.6506
# Epoch 73/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5895 - loss: 0.6483 - val_accuracy: 0.5933 - val_loss: 0.6501
# Epoch 74/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5901 - loss: 0.6515 - val_accuracy: 0.5978 - val_loss: 0.6479
# Epoch 75/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5964 - loss: 0.6496 - val_accuracy: 0.5928 - val_loss: 0.6476
# Epoch 76/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5917 - loss: 0.6457 - val_accuracy: 0.6000 - val_loss: 0.6466
# Epoch 77/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5973 - loss: 0.6477 - val_accuracy: 0.6089 - val_loss: 0.6471
# Epoch 78/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5906 - loss: 0.6464 - val_accuracy: 0.6100 - val_loss: 0.6439
# Epoch 79/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6018 - loss: 0.6440 - val_accuracy: 0.6150 - val_loss: 0.6431
# Epoch 80/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5992 - loss: 0.6429 - val_accuracy: 0.6156 - val_loss: 0.6423
# Epoch 81/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6052 - loss: 0.6437 - val_accuracy: 0.6178 - val_loss: 0.6402
# Epoch 82/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6051 - loss: 0.6398 - val_accuracy: 0.6150 - val_loss: 0.6388
# Epoch 83/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6071 - loss: 0.6392 - val_accuracy: 0.6144 - val_loss: 0.6383
# Epoch 84/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6081 - loss: 0.6409 - val_accuracy: 0.6172 - val_loss: 0.6367
# Epoch 85/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6036 - loss: 0.6397 - val_accuracy: 0.6200 - val_loss: 0.6339
# Epoch 86/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6099 - loss: 0.6385 - val_accuracy: 0.6183 - val_loss: 0.6348
# Epoch 87/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6098 - loss: 0.6353 - val_accuracy: 0.6261 - val_loss: 0.6307
# Epoch 88/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6146 - loss: 0.6350 - val_accuracy: 0.6244 - val_loss: 0.6281
# Epoch 89/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6173 - loss: 0.6318 - val_accuracy: 0.6250 - val_loss: 0.6258
# Epoch 90/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6150 - loss: 0.6318 - val_accuracy: 0.6239 - val_loss: 0.6268
# Epoch 91/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6162 - loss: 0.6334 - val_accuracy: 0.6261 - val_loss: 0.6249
# Epoch 92/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6226 - loss: 0.6271 - val_accuracy: 0.6250 - val_loss: 0.6212
# Epoch 93/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6181 - loss: 0.6307 - val_accuracy: 0.6261 - val_loss: 0.6213
# Epoch 94/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6190 - loss: 0.6280 - val_accuracy: 0.6322 - val_loss: 0.6221
# Epoch 95/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6246 - loss: 0.6249 - val_accuracy: 0.6211 - val_loss: 0.6176
# Epoch 96/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6260 - loss: 0.6252 - val_accuracy: 0.6233 - val_loss: 0.6147
# Epoch 97/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6252 - loss: 0.6223 - val_accuracy: 0.6306 - val_loss: 0.6120
# Epoch 98/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6356 - loss: 0.6194 - val_accuracy: 0.6328 - val_loss: 0.6090
# Epoch 99/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6386 - loss: 0.6198 - val_accuracy: 0.6250 - val_loss: 0.6095
# Epoch 100/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6367 - loss: 0.6172 - val_accuracy: 0.6433 - val_loss: 0.6049
# Epoch 101/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6385 - loss: 0.6155 - val_accuracy: 0.6417 - val_loss: 0.6037
# Epoch 102/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6465 - loss: 0.6097 - val_accuracy: 0.6428 - val_loss: 0.6054
# Epoch 103/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6439 - loss: 0.6115 - val_accuracy: 0.6478 - val_loss: 0.6026
# Epoch 104/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6487 - loss: 0.6111 - val_accuracy: 0.6478 - val_loss: 0.5986
# Epoch 105/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6473 - loss: 0.6128 - val_accuracy: 0.6417 - val_loss: 0.5982
# Epoch 106/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6486 - loss: 0.6110 - val_accuracy: 0.6406 - val_loss: 0.5977
# Epoch 107/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6504 - loss: 0.6090 - val_accuracy: 0.6483 - val_loss: 0.5962
# Epoch 108/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6506 - loss: 0.6060 - val_accuracy: 0.6433 - val_loss: 0.5958
# Epoch 109/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6548 - loss: 0.6024 - val_accuracy: 0.6511 - val_loss: 0.5923
# Epoch 110/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6608 - loss: 0.6031 - val_accuracy: 0.6506 - val_loss: 0.5919
# Epoch 111/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6665 - loss: 0.5992 - val_accuracy: 0.6528 - val_loss: 0.5902
# Epoch 112/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6583 - loss: 0.6014 - val_accuracy: 0.6500 - val_loss: 0.5894
# Epoch 113/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6670 - loss: 0.5989 - val_accuracy: 0.6506 - val_loss: 0.5867
# Epoch 114/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6646 - loss: 0.5969 - val_accuracy: 0.6511 - val_loss: 0.5847
# Epoch 115/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6682 - loss: 0.5943 - val_accuracy: 0.6489 - val_loss: 0.5860
# Epoch 116/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6630 - loss: 0.5974 - val_accuracy: 0.6528 - val_loss: 0.5842
# Epoch 117/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6620 - loss: 0.5935 - val_accuracy: 0.6539 - val_loss: 0.5821
# Epoch 118/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6686 - loss: 0.5929 - val_accuracy: 0.6594 - val_loss: 0.5818
# Epoch 119/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6642 - loss: 0.5950 - val_accuracy: 0.6578 - val_loss: 0.5794
# Epoch 120/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6711 - loss: 0.5862 - val_accuracy: 0.6539 - val_loss: 0.5788
# Epoch 121/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6596 - loss: 0.5944 - val_accuracy: 0.6494 - val_loss: 0.5783
# Epoch 122/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6771 - loss: 0.5887 - val_accuracy: 0.6500 - val_loss: 0.5802
# Epoch 123/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6676 - loss: 0.5899 - val_accuracy: 0.6594 - val_loss: 0.5738
# Epoch 124/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6710 - loss: 0.5920 - val_accuracy: 0.6633 - val_loss: 0.5727
# Epoch 125/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6710 - loss: 0.5850 - val_accuracy: 0.6539 - val_loss: 0.5753
# Epoch 126/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6754 - loss: 0.5841 - val_accuracy: 0.6611 - val_loss: 0.5683
# Epoch 127/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6712 - loss: 0.5836 - val_accuracy: 0.6633 - val_loss: 0.5675
# Epoch 128/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6813 - loss: 0.5795 - val_accuracy: 0.6583 - val_loss: 0.5683
# Epoch 129/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6783 - loss: 0.5780 - val_accuracy: 0.6594 - val_loss: 0.5626
# Epoch 130/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6785 - loss: 0.5770 - val_accuracy: 0.6583 - val_loss: 0.5624
# Epoch 131/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6701 - loss: 0.5802 - val_accuracy: 0.6589 - val_loss: 0.5601
# Epoch 132/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6807 - loss: 0.5748 - val_accuracy: 0.6556 - val_loss: 0.5557
# Epoch 133/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6858 - loss: 0.5726 - val_accuracy: 0.6611 - val_loss: 0.5552
# Epoch 134/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6904 - loss: 0.5679 - val_accuracy: 0.6794 - val_loss: 0.5551
# Epoch 135/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6870 - loss: 0.5704 - val_accuracy: 0.6744 - val_loss: 0.5493
# Epoch 136/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6946 - loss: 0.5662 - val_accuracy: 0.6806 - val_loss: 0.5467
# Epoch 137/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6854 - loss: 0.5679 - val_accuracy: 0.6900 - val_loss: 0.5459
# Epoch 138/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6942 - loss: 0.5658 - val_accuracy: 0.6861 - val_loss: 0.5443
# Epoch 139/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6907 - loss: 0.5640 - val_accuracy: 0.6978 - val_loss: 0.5393
# Epoch 140/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6962 - loss: 0.5593 - val_accuracy: 0.6906 - val_loss: 0.5395
# Epoch 141/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7032 - loss: 0.5563 - val_accuracy: 0.7000 - val_loss: 0.5327
# Epoch 142/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7057 - loss: 0.5548 - val_accuracy: 0.7033 - val_loss: 0.5332
# Epoch 143/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7064 - loss: 0.5512 - val_accuracy: 0.7083 - val_loss: 0.5269
# Epoch 144/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7114 - loss: 0.5489 - val_accuracy: 0.7122 - val_loss: 0.5257
# Epoch 145/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7068 - loss: 0.5511 - val_accuracy: 0.7178 - val_loss: 0.5195
# Epoch 146/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7145 - loss: 0.5438 - val_accuracy: 0.7178 - val_loss: 0.5166
# Epoch 147/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7185 - loss: 0.5386 - val_accuracy: 0.7278 - val_loss: 0.5136
# Epoch 148/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7179 - loss: 0.5409 - val_accuracy: 0.7506 - val_loss: 0.5093
# Epoch 149/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7289 - loss: 0.5334 - val_accuracy: 0.7483 - val_loss: 0.5039
# Epoch 150/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7288 - loss: 0.5290 - val_accuracy: 0.7550 - val_loss: 0.4978
# Epoch 151/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7288 - loss: 0.5309 - val_accuracy: 0.7611 - val_loss: 0.4934
# Epoch 152/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7363 - loss: 0.5293 - val_accuracy: 0.7694 - val_loss: 0.4875
# Epoch 153/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7457 - loss: 0.5181 - val_accuracy: 0.7617 - val_loss: 0.4882
# Epoch 154/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7457 - loss: 0.5228 - val_accuracy: 0.7744 - val_loss: 0.4807
# Epoch 155/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7471 - loss: 0.5132 - val_accuracy: 0.7706 - val_loss: 0.4772
# Epoch 156/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7476 - loss: 0.5148 - val_accuracy: 0.7728 - val_loss: 0.4730
# Epoch 157/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7521 - loss: 0.5146 - val_accuracy: 0.7822 - val_loss: 0.4672
# Epoch 158/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7545 - loss: 0.5065 - val_accuracy: 0.7811 - val_loss: 0.4665
# Epoch 159/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7556 - loss: 0.5051 - val_accuracy: 0.7850 - val_loss: 0.4623
# Epoch 160/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7606 - loss: 0.5011 - val_accuracy: 0.7783 - val_loss: 0.4576
# Epoch 161/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7575 - loss: 0.4994 - val_accuracy: 0.7811 - val_loss: 0.4569
# Epoch 162/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7642 - loss: 0.4948 - val_accuracy: 0.7828 - val_loss: 0.4552
# Epoch 163/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7571 - loss: 0.4995 - val_accuracy: 0.7889 - val_loss: 0.4574
# Epoch 164/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7625 - loss: 0.4902 - val_accuracy: 0.7883 - val_loss: 0.4473
# Epoch 165/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7644 - loss: 0.4986 - val_accuracy: 0.7950 - val_loss: 0.4457
# Epoch 166/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7642 - loss: 0.4911 - val_accuracy: 0.7906 - val_loss: 0.4457
# Epoch 167/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7636 - loss: 0.4911 - val_accuracy: 0.7889 - val_loss: 0.4525
# Epoch 168/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7658 - loss: 0.4900 - val_accuracy: 0.7911 - val_loss: 0.4414
# Epoch 169/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7642 - loss: 0.4858 - val_accuracy: 0.7911 - val_loss: 0.4428
# Epoch 170/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7751 - loss: 0.4763 - val_accuracy: 0.7989 - val_loss: 0.4364
# Epoch 171/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7679 - loss: 0.4826 - val_accuracy: 0.7917 - val_loss: 0.4429
# Epoch 172/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7694 - loss: 0.4819 - val_accuracy: 0.7978 - val_loss: 0.4330
# Epoch 173/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7699 - loss: 0.4824 - val_accuracy: 0.7967 - val_loss: 0.4377
# Epoch 174/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7700 - loss: 0.4834 - val_accuracy: 0.8028 - val_loss: 0.4349
# Epoch 175/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7704 - loss: 0.4824 - val_accuracy: 0.8017 - val_loss: 0.4347
# Epoch 176/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7693 - loss: 0.4824 - val_accuracy: 0.8078 - val_loss: 0.4337
# Epoch 177/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7786 - loss: 0.4797 - val_accuracy: 0.8011 - val_loss: 0.4390
# Epoch 178/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7755 - loss: 0.4803 - val_accuracy: 0.7994 - val_loss: 0.4373
# Epoch 179/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7757 - loss: 0.4710 - val_accuracy: 0.8056 - val_loss: 0.4316
# Epoch 180/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7756 - loss: 0.4729 - val_accuracy: 0.8022 - val_loss: 0.4300
# Epoch 181/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7773 - loss: 0.4813 - val_accuracy: 0.8028 - val_loss: 0.4318
# Epoch 182/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7811 - loss: 0.4666 - val_accuracy: 0.8106 - val_loss: 0.4244
# Epoch 183/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7775 - loss: 0.4762 - val_accuracy: 0.8044 - val_loss: 0.4350
# Epoch 184/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7740 - loss: 0.4730 - val_accuracy: 0.7989 - val_loss: 0.4345
# Epoch 185/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7823 - loss: 0.4733 - val_accuracy: 0.8072 - val_loss: 0.4305
# Epoch 186/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7754 - loss: 0.4747 - val_accuracy: 0.8061 - val_loss: 0.4327
# Epoch 187/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7801 - loss: 0.4759 - val_accuracy: 0.8106 - val_loss: 0.4311
# Epoch 188/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7744 - loss: 0.4739 - val_accuracy: 0.8067 - val_loss: 0.4329
# Epoch 189/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7794 - loss: 0.4688 - val_accuracy: 0.8072 - val_loss: 0.4208
# Epoch 190/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7740 - loss: 0.4714 - val_accuracy: 0.8111 - val_loss: 0.4249
# Epoch 191/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7806 - loss: 0.4672 - val_accuracy: 0.8078 - val_loss: 0.4257
# Epoch 192/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7785 - loss: 0.4669 - val_accuracy: 0.8100 - val_loss: 0.4277
# Epoch 193/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7787 - loss: 0.4690 - val_accuracy: 0.8122 - val_loss: 0.4190
# Epoch 194/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7764 - loss: 0.4648 - val_accuracy: 0.8150 - val_loss: 0.4176
# Epoch 195/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7796 - loss: 0.4655 - val_accuracy: 0.8150 - val_loss: 0.4258
# Epoch 196/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7800 - loss: 0.4726 - val_accuracy: 0.8194 - val_loss: 0.4188
# Epoch 197/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7831 - loss: 0.4630 - val_accuracy: 0.8167 - val_loss: 0.4203
# Epoch 198/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7836 - loss: 0.4620 - val_accuracy: 0.8178 - val_loss: 0.4176
# Epoch 199/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7835 - loss: 0.4647 - val_accuracy: 0.8167 - val_loss: 0.4251
# Epoch 200/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7814 - loss: 0.4631 - val_accuracy: 0.8133 - val_loss: 0.4221

# %%
fig,AX=plt.subplots(1,2,figsize=(12,5.))
ax=AX[0]
ax.plot(fit.history['accuracy'],label="train",c="b",ls="--")
ax.plot(fit.history['val_accuracy'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Accuracy")
ax.legend()
ax=AX[1]
ax.plot(fit.history['loss'],label="train",c="b",ls="--")
ax.plot(fit.history['val_loss'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Loss")
ax.legend()

# %% [markdown]
# # Evaluation on the test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Final test loss: {test_loss:.4f}")
print(f"Final test accuracy: {test_acc:.4f}")
# Out:
# Final test loss: 0.4141
# Final test accuracy: 0.8178

# %% [markdown]
# ## Grid to show preditions

# %%
dX = .1
X1 = np.arange(0,10+dX, dX)
LG = len(X1)
# 2D meshgrid
X, Y = np.meshgrid(X1, X1)
allXY = np.reshape((np.array((X,Y)).T),(LG**2,2))
#create synthetic inputs with L features for each grid point; initialized randomly in [0, B].
grid = np.random.rand(LG**2,L)*B
#replace first 2 features with the actual 2D coordinates
grid[:,:2] = allXY
#standardize using train-set mean/std before prediction
grid_r=Standardize(grid,x_train_mean,x_train_std)

pred = model.predict(grid_r)

fig,AX=plt.subplots(1,3,figsize=(16,5.))
ax=AX[0]
ax.scatter(x[:,0],x[:,1],c=y,s=6)
ax.set_title("data")
ax=AX[1]
ax.pcolormesh(X1,X1,pred.reshape((LG, LG)))
ax.set_title("prediction $\\hat y$")
ax=AX[2]
pred01=np.copy(pred)
pred01[pred>0.5]=1
pred01[pred<=0.5]=0
ax.pcolormesh(X1,X1,pred01.reshape((LG, LG)))
ax.set_title("where $\\hat y > 1/2$")
plt.show()
print(f"remember: these are 2 out of L={L} dimensions, of which L-2 contain random noise")
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# remember: these are 2 out of L=8 dimensions, of which L-2 contain random noise
