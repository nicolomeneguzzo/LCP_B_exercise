# %% [markdown]
# # DNN: analysis with Keras of 2D data

# %% [markdown]
# # Keras Tuner
# check https://keras.io/keras_tuner/getting_started/ or just pip install keras-tuner -q
#
# install tensorflow

# %%
import numpy as np

from keras.models import Sequential
from keras.layers import Dense, Dropout

import matplotlib as mpl
import matplotlib.pyplot as plt
# default font
plt.rcParams['font.size'] = 13

from sklearn.preprocessing import StandardScaler

# %run useful.py

# training/validation/test fractions
perc_train = 0.7
perc_valid = 0.15
perc_test = 0.15
#  check it sums to 1 
assert abs(perc_train + perc_valid + perc_test - 1.0) < 1e-12

# %% [markdown]
# ## Read data

# %%
# Keras works with numpy arrays: just use them from the start

TYPE=3
# number of features per sample
L=8
# span of each component
B=10
x = np.loadtxt(filename("data",L,TYPE), delimiter=' ')
y = np.loadtxt(filename("labels",L,TYPE), delimiter=' ')
y = y.astype("int")
print(x.shape)
N = len(x)


# dim. of a sample
L = len(x[0])
print(L)

for i in range(5):
    print(x[i],y[i])

N_train = int(perc_train * N)
N_valid = int(perc_valid * N)
N_test = N - N_train - N_valid
print(f'data: {N}\ntrain: {N_train}\nvalid: {N_valid}\ntest: {N_test}')

plot_data(x,y)
# Out:
# (12000, 8)
# 8
# [1.83918812 2.04560279 5.67725029 5.95544703 9.6451452  6.53177097
#  7.48906638 6.53569871] 1
# [7.47714809 9.61306736 0.08388298 1.06444377 2.98703714 6.56411183
#  8.09812553 8.72175914] 0
# [9.64647597 7.23685347 6.42475328 7.17453621 4.67599007 3.25584678
#  4.39644606 7.29689083] 0
# [9.94014586 6.76873712 7.90822518 1.70914258 0.26849276 8.00370244
#  9.03722538 0.2467621 ] 0
# [4.91747318 5.26255167 5.9636601  0.51957545 8.95089528 7.2826618
#  8.18350011 5.00222753] 1
# data: 12000
# train: 8400
# valid: 1800
# test: 1800

# %% [markdown]
# ## Split data and standardize (fit on train only)

# %%
def Standardize(x,m,s):
    """
    rescale each component using its mean and standard deviation
    x: data points (numpy array)
    m: mean values (numpy array)
    s: standard deviations (numpy array)
    return: rescaled data points (numpy array)
    """
    N = len(x)
    # assuming len(m)=len(s)=len(x[0])
    mm,ss = np.tile(m,(N,1)), np.tile(s,(N,1))
    return (x-mm)/ss

# split data into train/validation/test sets and check 
(x_train, y_train) = (x[0:N_train],y[0:N_train])
(x_valid, y_valid) = (x[N_train:N_train+N_valid],y[N_train:N_train+N_valid])
(x_test, y_test) = (x[N_train+N_valid:],y[N_train+N_valid:])
print("Train:",len(x_train),"\t Validation:",len(x_valid),"\t Test:",len(x_test))


x_train_mean = np.mean(x_train, axis=0)
x_train_std = np.std(x_train, axis=0)
#print("train stats before rescaling:\nmean value=", x_train_mean, "\nstd. dev.=", x_train_std)

x_valid_mean = np.mean(x_valid, axis=0)
x_valid_std = np.std(x_valid, axis=0)
#print("validation stats before rescaling:\nmean value=", x_valid_mean, "\nstd. dev.=", x_valid_std)

x_test_mean = np.mean(x_test, axis=0)
x_test_std = np.std(x_test, axis=0)
#print("test stats before rescaling:\nmean value=", x_test_mean, "\nstd. dev.=", x_test_std)

x_train = Standardize(x_train, x_train_mean, x_train_std)
x_valid = Standardize(x_valid, x_valid_mean, x_valid_std)
x_test = Standardize(x_test, x_test_mean, x_test_std)
print("after rescaling (train):\nmean value=", x_train.mean(axis=0), "\nstd. dev.=", x_train.std(axis=0))
# Out:
# Train: 8400 	 Validation: 1800 	 Test: 1800
# after rescaling (train):
# mean value= [ 9.17572896e-16  1.18834043e-14 -1.95478554e-15 -3.53337069e-15
#  -6.42594443e-15 -2.40365928e-15 -2.88332932e-15 -8.27623684e-15]
# std. dev.= [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Define the model with Keras / Tensorflow

# %%
# reproducibility (?)
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

# We use case 1
CASE=1

if CASE==1:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
# as case 1 but one layer shorter
if CASE==2:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(40,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(20,activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
#deeper
if CASE==3:
    model = Sequential()
    model.add(Dense(L,input_shape=(L,),activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    nepoch=200
    
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 20)             │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 20)             │           420 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,113 (4.35 KB)
#  Trainable params: 1,113 (4.35 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Optimization method and cost function

# %%
model.compile(loss='binary_crossentropy',
              optimizer='RMSprop',
              #optimizer='adam',
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
fit = model.fit(x_train, y_train,
               epochs = nepoch, batch_size = 50,
               validation_data=(x_valid,y_valid),
               verbose=2)
# Out:
# Epoch 1/200
# 168/168 - 4s - 21ms/step - accuracy: 0.5231 - loss: 0.6879 - val_accuracy: 0.5289 - val_loss: 0.6767
# Epoch 2/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5346 - loss: 0.6768 - val_accuracy: 0.5428 - val_loss: 0.6665
# Epoch 3/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5357 - loss: 0.6675 - val_accuracy: 0.5444 - val_loss: 0.6538
# Epoch 4/200
# 168/168 - 0s - 3ms/step - accuracy: 0.5651 - loss: 0.6503 - val_accuracy: 0.5811 - val_loss: 0.6372
# Epoch 5/200
# 168/168 - 0s - 2ms/step - accuracy: 0.5933 - loss: 0.6344 - val_accuracy: 0.6161 - val_loss: 0.6207
# Epoch 6/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6339 - loss: 0.6147 - val_accuracy: 0.6483 - val_loss: 0.6029
# Epoch 7/200
# 168/168 - 0s - 2ms/step - accuracy: 0.6507 - loss: 0.5993 - val_accuracy: 0.6833 - val_loss: 0.5857
# Epoch 8/200
# 168/168 - 0s - 3ms/step - accuracy: 0.6693 - loss: 0.5822 - val_accuracy: 0.7028 - val_loss: 0.5697
# Epoch 9/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7004 - loss: 0.5569 - val_accuracy: 0.7211 - val_loss: 0.5503
# Epoch 10/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7163 - loss: 0.5458 - val_accuracy: 0.7256 - val_loss: 0.5320
# Epoch 11/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7330 - loss: 0.5225 - val_accuracy: 0.7417 - val_loss: 0.5100
# Epoch 12/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7471 - loss: 0.5013 - val_accuracy: 0.7650 - val_loss: 0.4812
# Epoch 13/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7671 - loss: 0.4786 - val_accuracy: 0.7878 - val_loss: 0.4496
# Epoch 14/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7806 - loss: 0.4488 - val_accuracy: 0.7978 - val_loss: 0.4203
# Epoch 15/200
# 168/168 - 0s - 2ms/step - accuracy: 0.7937 - loss: 0.4281 - val_accuracy: 0.8122 - val_loss: 0.3973
# Epoch 16/200
# 168/168 - 0s - 3ms/step - accuracy: 0.7971 - loss: 0.4156 - val_accuracy: 0.8200 - val_loss: 0.3799
# Epoch 17/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8064 - loss: 0.3982 - val_accuracy: 0.8261 - val_loss: 0.3597
# Epoch 18/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8202 - loss: 0.3826 - val_accuracy: 0.8317 - val_loss: 0.3395
# Epoch 19/200
# 168/168 - 0s - 2ms/step - accuracy: 0.8260 - loss: 0.3620 - val_accuracy: 0.8467 - val_loss: 0.3176
# Epoch 20/200
# 168/168 - 0s - 2ms/step - accuracy: 0.8386 - loss: 0.3427 - val_accuracy: 0.8611 - val_loss: 0.2938
# Epoch 21/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8521 - loss: 0.3195 - val_accuracy: 0.8850 - val_loss: 0.2647
# Epoch 22/200
# 168/168 - 0s - 2ms/step - accuracy: 0.8627 - loss: 0.2968 - val_accuracy: 0.9067 - val_loss: 0.2380
# Epoch 23/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8713 - loss: 0.2824 - val_accuracy: 0.9150 - val_loss: 0.2173
# Epoch 24/200
# 168/168 - 0s - 2ms/step - accuracy: 0.8851 - loss: 0.2593 - val_accuracy: 0.9239 - val_loss: 0.2004
# Epoch 25/200
# 168/168 - 0s - 3ms/step - accuracy: 0.8919 - loss: 0.2432 - val_accuracy: 0.9289 - val_loss: 0.1797
# Epoch 26/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9001 - loss: 0.2292 - val_accuracy: 0.9317 - val_loss: 0.1707
# Epoch 27/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9093 - loss: 0.2148 - val_accuracy: 0.9372 - val_loss: 0.1505
# Epoch 28/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9135 - loss: 0.1998 - val_accuracy: 0.9506 - val_loss: 0.1344
# Epoch 29/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9183 - loss: 0.1914 - val_accuracy: 0.9517 - val_loss: 0.1271
# Epoch 30/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9217 - loss: 0.1848 - val_accuracy: 0.9528 - val_loss: 0.1231
# Epoch 31/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9257 - loss: 0.1767 - val_accuracy: 0.9483 - val_loss: 0.1258
# Epoch 32/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9295 - loss: 0.1659 - val_accuracy: 0.9583 - val_loss: 0.1123
# Epoch 33/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9337 - loss: 0.1582 - val_accuracy: 0.9533 - val_loss: 0.1204
# Epoch 34/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9305 - loss: 0.1597 - val_accuracy: 0.9539 - val_loss: 0.1176
# Epoch 35/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9351 - loss: 0.1574 - val_accuracy: 0.9578 - val_loss: 0.1050
# Epoch 36/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9437 - loss: 0.1395 - val_accuracy: 0.9594 - val_loss: 0.0972
# Epoch 37/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9405 - loss: 0.1400 - val_accuracy: 0.9628 - val_loss: 0.0945
# Epoch 38/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9435 - loss: 0.1384 - val_accuracy: 0.9639 - val_loss: 0.0903
# Epoch 39/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9425 - loss: 0.1317 - val_accuracy: 0.9578 - val_loss: 0.1059
# Epoch 40/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9446 - loss: 0.1348 - val_accuracy: 0.9650 - val_loss: 0.0848
# Epoch 41/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9443 - loss: 0.1306 - val_accuracy: 0.9633 - val_loss: 0.0862
# Epoch 42/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9463 - loss: 0.1280 - val_accuracy: 0.9639 - val_loss: 0.0822
# Epoch 43/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9511 - loss: 0.1201 - val_accuracy: 0.9650 - val_loss: 0.0831
# Epoch 44/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9489 - loss: 0.1243 - val_accuracy: 0.9628 - val_loss: 0.0914
# Epoch 45/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9543 - loss: 0.1173 - val_accuracy: 0.9622 - val_loss: 0.0877
# Epoch 46/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9548 - loss: 0.1153 - val_accuracy: 0.9650 - val_loss: 0.0860
# Epoch 47/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9571 - loss: 0.1129 - val_accuracy: 0.9644 - val_loss: 0.0819
# Epoch 48/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9562 - loss: 0.1107 - val_accuracy: 0.9650 - val_loss: 0.0759
# Epoch 49/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9579 - loss: 0.1046 - val_accuracy: 0.9639 - val_loss: 0.0842
# Epoch 50/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9593 - loss: 0.1014 - val_accuracy: 0.9694 - val_loss: 0.0763
# Epoch 51/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9582 - loss: 0.1039 - val_accuracy: 0.9683 - val_loss: 0.0703
# Epoch 52/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9579 - loss: 0.1029 - val_accuracy: 0.9628 - val_loss: 0.0919
# Epoch 53/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9596 - loss: 0.1003 - val_accuracy: 0.9722 - val_loss: 0.0669
# Epoch 54/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9617 - loss: 0.0956 - val_accuracy: 0.9767 - val_loss: 0.0586
# Epoch 55/200
# 168/168 - 0s - 2ms/step - accuracy: 0.
200
# 168/168 - 0s - 2ms/step - accuracy: 0.9815 - loss: 0.0565 - val_accuracy: 0.9756 - val_loss: 0.0584
# Epoch 188/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9788 - loss: 0.0571 - val_accuracy: 0.9800 - val_loss: 0.0506
# Epoch 189/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9795 - loss: 0.0569 - val_accuracy: 0.9772 - val_loss: 0.0566
# Epoch 190/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9776 - loss: 0.0634 - val_accuracy: 0.9767 - val_loss: 0.0514
# Epoch 191/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9795 - loss: 0.0560 - val_accuracy: 0.9761 - val_loss: 0.0597
# Epoch 192/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9789 - loss: 0.0600 - val_accuracy: 0.9783 - val_loss: 0.0509
# Epoch 193/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9785 - loss: 0.0581 - val_accuracy: 0.9744 - val_loss: 0.0648
# Epoch 194/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9775 - loss: 0.0575 - val_accuracy: 0.9761 - val_loss: 0.0574
# Epoch 195/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9813 - loss: 0.0518 - val_accuracy: 0.9711 - val_loss: 0.0701
# Epoch 196/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9776 - loss: 0.0594 - val_accuracy: 0.9700 - val_loss: 0.0744
# Epoch 197/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9796 - loss: 0.0580 - val_accuracy: 0.9756 - val_loss: 0.0607
# Epoch 198/200
# 168/168 - 0s - 2ms/step - accuracy: 0.9783 - loss: 0.0627 - val_accuracy: 0.9783 - val_loss: 0.0539
# Epoch 199/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9798 - loss: 0.0566 - val_accuracy: 0.9744 - val_loss: 0.0600
# Epoch 200/200
# 168/168 - 0s - 3ms/step - accuracy: 0.9794 - loss: 0.0599 - val_accuracy: 0.9778 - val_loss: 0.0598

# %%
fig,AX=plt.subplots(1,2,figsize=(12,5.))
ax=AX[0]
ax.plot(fit.history['accuracy'],label="train",c="b",ls="--")
ax.plot(fit.history['val_accuracy'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Accuracy")
ax.legend()
ax=AX[1]
ax.plot(fit.history['loss'],label="train",c="b",ls="--")
ax.plot(fit.history['val_loss'],label="valid.",c="r")
ax.set_xlabel('epoch')
ax.set_ylabel("Loss")
ax.legend()

# %% [markdown]
# # Evaluation on the test set

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Final test loss: {test_loss:.4f}")
print(f"Final test accuracy: {test_acc:.4f}")
# Out:
# Final test loss: 0.0701
# Final test accuracy: 0.9739

# %% [markdown]
# ## Grid to show preditions

# %%
dX = .1
X1 = np.arange(0,10+dX, dX)
LG = len(X1)
# 2D meshgrid
X, Y = np.meshgrid(X1, X1)
allXY = np.reshape((np.array((X,Y)).T),(LG**2,2))
#create synthetic inputs with L features for each grid point; initialized randomly in [0, B].
grid = np.random.rand(LG**2,L)*B
#replace first 2 features with the actual 2D coordinates
grid[:,:2] = allXY
#standardize using train-set mean/std before prediction
grid_r=Standardize(grid,x_train_mean,x_train_std)

pred = model.predict(grid_r)

fig,AX=plt.subplots(1,3,figsize=(16,5.))
ax=AX[0]
ax.scatter(x[:,0],x[:,1],c=y,s=6)
ax.set_title("data")
ax=AX[1]
ax.pcolormesh(X1,X1,pred.reshape((LG, LG)))
ax.set_title("prediction $\\hat y$")
ax=AX[2]
pred01=np.copy(pred)
pred01[pred>0.5]=1
pred01[pred<=0.5]=0
ax.pcolormesh(X1,X1,pred01.reshape((LG, LG)))
ax.set_title("where $\\hat y > 1/2$")
plt.show()
print(f"remember: these are 2 out of L={L} dimensions, of which L-2 contain random noise")
# Out:
# 319/319 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# remember: these are 2 out of L=8 dimensions, of which L-2 contain random noise
