# %% [markdown]
# ### CNNs applied to time series

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 14

import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten #, Reshape
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D

# %run plot.py
# Out:
# 2026-03-12 14:48:07.064353: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-12 14:48:07.159616: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Read data

# %%
str0 = 'ts_L60_Z12_A500_DX50_bias5_N10000.dat'
fnamex='DATA/x_'+str0
fnamey='DATA/y_'+str0

x = np.loadtxt(fnamex, delimiter=" ",dtype=float)
# number of samples, number of features
N,L = len(x), len(x[0])

Show_data(x,L,"original data")

categ = np.loadtxt(fnamey, dtype=int)
n_class = 3    # y.argmax() - y.argmin() +1
print('data: ',N)

y = np.zeros((N,n_class))
for i in range(N):
    y[i][categ[i]] = 1. # y contains one-hot encoding
# Out:
# data:  10000

# %% [markdown]
# ### Split train-validation and rescale

# %%
# split into training and validation sets
perc_train=0.8
N_train = int(perc_train*N)
x_train = x[:N_train]
print(x_train.shape)
y_train = y[:N_train]
x_val = x[N_train:]
y_val = y[N_train:]
N_val = len(x_val)
print('N_train=',N_train,'  N_val=',N_val,'  L=',L,'  n_class=',n_class)

 
#remove average value of each sample from its values
xm_train = x_train.mean(axis=1)
std_train = x_train.std(axis=1)
xm_val = x_val.mean(axis=1)
std_val = x_val.std(axis=1)
print('std_train average and mean:',max(std_train), min(std_train), std_train.mean(axis=0))
print('std_val average and mean:',max(std_val), min(std_val), std_val.mean(axis=0))

# rescale with variance on the training set
for i in range(N_train):
    #x_train[i] = (x_train[i]-xm_train[i])/ std_train[i] #not good, std_train is very variable across samples
     #x_train[i] = (x_train[i]-xm_train[i])/ 400 #crude rescaling, variance should be used
     x_train[i] = (x_train[i]-xm_train[i])/ std_train.mean(axis=0)
for i in range(N_val):
    #x_val[i] = (x_val[i]-xm_val[i])/ std_val[i]
    #x_val[i] = (x_val[i]-xm_val[i])/ 400
    x_val[i] = (x_val[i]-xm_val[i])/ std_val.mean(axis=0)
#

    
Show_data(x_train,L,"rescaled train data")
Show_data(x_val,L,"rescaled validation data")

#x_train=x_train.astype("float32")
#y_train=y_train.astype("float32")
#x_val=x_val.astype("float32")
#y_val=y_val.astype("float32")

# Keras wants an additional dimension with a 1 at the end
x_train = x_train.reshape(x_train.shape[0], L, 1)
x_val =  x_val.reshape(x_val.shape[0], L, 1)
input_shape = (L, 1) # number of features, number of channels (1 for 1D data)
# Out:
# (8000, 60)
# N_train= 8000   N_val= 2000   L= 60   n_class= 3
# std_train average and mean: 588.25397835931 44.84287073276593 201.46657645528722
# std_val average and mean: 569.9090424503428 55.06717110341998 201.92178219610327

# %% [markdown]
# ## Convolutional NN

# %%
# ...LESSON ...
# reproducibility
np.random.seed(12345)
import tensorflow.random as tf_r
tf_r.set_seed(12345)

## from keras import regularizers, initializers

reg = tf.keras.regularizers.l2(0.2) ## raised to 0.2 the regularization strenghts
#reg = regularizers.l1(0.1)
ini = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05, 
                                        seed=None)
NCONV = 1 #swtich between 1 and 2 CNNs
NF = 5 #number of filters

# challenge: at most 600 tunable parameters
model = Sequential()
# 
if NCONV==1:
    # -----2-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg,
                     activation='relu', 
                     input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Conv1D(filters=5, kernel_size=7, 
                     activation='relu'))
    model.add(Flatten())
    model.add(Dense(12, activation='relu'))
    model.add(Dropout(0.2))
# 
if NCONV==2:
    # -----1-----
    model.add(Conv1D(filters=NF, kernel_size=11, 
                     kernel_initializer=ini, 
                     kernel_regularizer=reg, ######## TRY WITHOUT !
                     activation='relu', input_shape=input_shape))
    #model.add(MaxPooling1D(3))
    model.add(AveragePooling1D(5))
    model.add(Flatten())
    model.add(Dense(9, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(6, activation='relu'))
    model.add(Dropout(0.2))
    #model.add(Dense(10, activation='relu'))
    #model.add(Dropout(0.3))
model.add(Dense(n_class, activation='softmax')) # softmax !

print('----- Model',NCONV,'-----')
print(model.summary())

# optimizers
# .SGD(lr=0.01, momentum=0.9, nesterov=True) # decay=1e-6,
# .RMSprop()
# .Nadam()
opt = tf.keras.optimizers.Adam()

# compile the model
# categorical_crossentropy, 3 output nodes
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=opt,metrics=['accuracy'])
# Out:
# ----- Model 1 -----
# /home/ettore/anaconda3/envs/LCPB_env/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 50, 5)          │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling1d               │ (None, 10, 5)          │             0 │
# │ (AveragePooling1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 4, 5)           │           180 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 12)             │           252 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            39 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 531 (2.07 KB)
#  Trainable params: 531 (2.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.layers
# Out:
# [<Conv1D name=conv1d, built=True>,
#  <AveragePooling1D name=average_pooling1d, built=True>,
#  <Conv1D name=conv1d_1, built=True>,
#  <Flatten name=flatten, built=True>,
#  <Dense name=dense, built=True>,
#  <Dropout name=dropout, built=True>,
#  <Dense name=dense_1, built=True>]

# %%
def Show_weights(model,l=0,label="model"):
    c=['r','y','c','b','m']
    m=['o','s','D','<','>']
    ms=10
    
    w = model.layers[l].get_weights()[0] # weights
    print(w.shape)
    wT=w.T
    print(wT.shape)
    M=len(wT)
    b = model.layers[l].get_weights()[1] # bias
    
    fig,AX=plt.subplots(1,2,figsize=(12,4.4))
    ax=AX[0]
    ax.axhline(0, c="k")
    ax.plot((0,))
    for i in range(M):
        ax.plot(wT[i][0],"-",c=c[i],marker=m[i],label=str(i),markersize=ms)
    ax.set_title(label+': filters of layer '+str(l))
    ax.set_xlabel('index')
    ax=AX[1]
    ax.axhline(0, c="k")
    for i in range(M):
        ax.plot((i),(b[i]),c=c[i],marker=m[i],label="filter "+str(i),markersize=ms)
    ax.set_title(label+': bias of layer '+str(l))
    ax.set_xlabel('filter nr')
    ax.set_xticks(np.arange(5))
    ax.legend()
    plt.show()
    
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
# Hyper-parameters
# with small minibatch it does not converge!! 
BATCH_SIZE = 200
EPOCHS = 150

print('----- Model ',NCONV,'-----\nFITTING....')
fit = model.fit(x_train,y_train,batch_size=BATCH_SIZE,
                epochs=EPOCHS,
                validation_data=(x_val, y_val),
                verbose=2, shuffle=True)
# Out:
# ----- Model  1 -----
# FITTING....
# Epoch 1/150
# 40/40 - 2s - 39ms/step - accuracy: 0.3428 - loss: 1.1178 - val_accuracy: 0.4115 - val_loss: 1.1032
# Epoch 2/150
# 40/40 - 1s - 13ms/step - accuracy: 0.3975 - loss: 1.0964 - val_accuracy: 0.4115 - val_loss: 1.0891
# Epoch 3/150
# 40/40 - 0s - 11ms/step - accuracy: 0.4563 - loss: 1.0746 - val_accuracy: 0.5610 - val_loss: 1.0491
# Epoch 4/150
# 40/40 - 0s - 3ms/step - accuracy: 0.5414 - loss: 1.0048 - val_accuracy: 0.6450 - val_loss: 0.9363
# Epoch 5/150
# 40/40 - 0s - 8ms/step - accuracy: 0.6068 - loss: 0.8934 - val_accuracy: 0.6810 - val_loss: 0.8170
# Epoch 6/150
# 40/40 - 1s - 16ms/step - accuracy: 0.6410 - loss: 0.8122 - val_accuracy: 0.7190 - val_loss: 0.7385
# Epoch 7/150
# 40/40 - 1s - 24ms/step - accuracy: 0.6790 - loss: 0.7459 - val_accuracy: 0.7490 - val_loss: 0.6817
# Epoch 8/150
# 40/40 - 1s - 21ms/step - accuracy: 0.7066 - loss: 0.6987 - val_accuracy: 0.7745 - val_loss: 0.6311
# Epoch 9/150
# 40/40 - 1s - 17ms/step - accuracy: 0.7326 - loss: 0.6546 - val_accuracy: 0.7995 - val_loss: 0.5852
# Epoch 10/150
# 40/40 - 1s - 22ms/step - accuracy: 0.7609 - loss: 0.6129 - val_accuracy: 0.8240 - val_loss: 0.5393
# Epoch 11/150
# 40/40 - 1s - 19ms/step - accuracy: 0.7862 - loss: 0.5687 - val_accuracy: 0.8460 - val_loss: 0.4947
# Epoch 12/150
# 40/40 - 1s - 18ms/step - accuracy: 0.8048 - loss: 0.5401 - val_accuracy: 0.8645 - val_loss: 0.4615
# Epoch 13/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8244 - loss: 0.5086 - val_accuracy: 0.8750 - val_loss: 0.4341
# Epoch 14/150
# 40/40 - 1s - 17ms/step - accuracy: 0.8332 - loss: 0.4876 - val_accuracy: 0.8805 - val_loss: 0.4103
# Epoch 15/150
# 40/40 - 1s - 21ms/step - accuracy: 0.8480 - loss: 0.4587 - val_accuracy: 0.8880 - val_loss: 0.3851
# Epoch 16/150
# 40/40 - 1s - 21ms/step - accuracy: 0.8640 - loss: 0.4216 - val_accuracy: 0.8915 - val_loss: 0.3628
# Epoch 17/150
# 40/40 - 0s - 12ms/step - accuracy: 0.8615 - loss: 0.4135 - val_accuracy: 0.8985 - val_loss: 0.3488
# Epoch 18/150
# 40/40 - 1s - 15ms/step - accuracy: 0.8730 - loss: 0.3919 - val_accuracy: 0.9020 - val_loss: 0.3313
# Epoch 19/150
# 40/40 - 1s - 22ms/step - accuracy: 0.8763 - loss: 0.3780 - val_accuracy: 0.9090 - val_loss: 0.3160
# Epoch 20/150
# 40/40 - 1s - 19ms/step - accuracy: 0.8830 - loss: 0.3676 - val_accuracy: 0.9115 - val_loss: 0.3034
# Epoch 21/150
# 40/40 - 1s - 16ms/step - accuracy: 0.8870 - loss: 0.3482 - val_accuracy: 0.9165 - val_loss: 0.2919
# Epoch 22/150
# 40/40 - 0s - 5ms/step - accuracy: 0.8981 - loss: 0.3347 - val_accuracy: 0.9230 - val_loss: 0.2777
# Epoch 23/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8972 - loss: 0.3247 - val_accuracy: 0.9265 - val_loss: 0.2664
# Epoch 24/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9064 - loss: 0.3100 - val_accuracy: 0.9295 - val_loss: 0.2573
# Epoch 25/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9111 - loss: 0.2980 - val_accuracy: 0.9345 - val_loss: 0.2468
# Epoch 26/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9106 - loss: 0.2937 - val_accuracy: 0.9345 - val_loss: 0.2395
# Epoch 27/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9191 - loss: 0.2747 - val_accuracy: 0.9375 - val_loss: 0.2291
# Epoch 28/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9227 - loss: 0.2686 - val_accuracy: 0.9380 - val_loss: 0.2246
# Epoch 29/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9244 - loss: 0.2557 - val_accuracy: 0.9395 - val_loss: 0.2139
# Epoch 30/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9255 - loss: 0.2539 - val_accuracy: 0.9430 - val_loss: 0.2088
# Epoch 31/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9240 - loss: 0.2544 - val_accuracy: 0.9450 - val_loss: 0.2051
# Epoch 32/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9284 - loss: 0.2433 - val_accuracy: 0.9485 - val_loss: 0.1999
# Epoch 33/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9304 - loss: 0.2411 - val_accuracy: 0.9475 - val_loss: 0.1966
# Epoch 34/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9296 - loss: 0.2372 - val_accuracy: 0.9510 - val_loss: 0.1913
# Epoch 35/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9348 - loss: 0.2288 - val_accuracy: 0.9525 - val_loss: 0.1864
# Epoch 36/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9346 - loss: 0.2242 - val_accuracy: 0.9520 - val_loss: 0.1837
# Epoch 37/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9356 - loss: 0.2214 - val_accuracy: 0.9555 - val_loss: 0.1813
# Epoch 38/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9380 - loss: 0.2185 - val_accuracy: 0.9545 - val_loss: 0.1767
# Epoch 39/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9340 - loss: 0.2152 - val_accuracy: 0.9570 - val_loss: 0.1742
# Epoch 40/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9358 - loss: 0.2137 - val_accuracy: 0.9565 - val_loss: 0.1707
# Epoch 41/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9370 - loss: 0.2109 - val_accuracy: 0.9575 - val_loss: 0.1672
# Epoch 42/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9405 - loss: 0.1994 - val_accuracy: 0.9575 - val_loss: 0.1646
# Epoch 43/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9409 - loss: 0.2045 - val_accuracy: 0.9595 - val_loss: 0.1628
# Epoch 44/150
# 40/40 - 1s - 23ms/step - accuracy: 0.9380 - loss: 0.2055 - val_accuracy: 0.9600 - val_loss: 0.1618
# Epoch 45/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9413 - loss: 0.2011 - val_accuracy: 0.9610 - val_loss: 0.1588
# Epoch 46/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9430 - loss: 0.1968 - val_accuracy: 0.9605 - val_loss: 0.1569
# Epoch 47/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9454 - loss: 0.1916 - val_accuracy: 0.9605 - val_loss: 0.1551
# Epoch 48/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9476 - loss: 0.1914 - val_accuracy: 0.9620 - val_loss: 0.1547
# Epoch 49/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9450 - loss: 0.1865 - val_accuracy: 0.9615 - val_loss: 0.1524
# Epoch 50/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9446 - loss: 0.1900 - val_accuracy: 0.9610 - val_loss: 0.1505
# Epoch 51/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9474 - loss: 0.1852 - val_accuracy: 0.9630 - val_loss: 0.1475
# Epoch 52/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9499 - loss: 0.1856 - val_accuracy: 0.9620 - val_loss: 0.1482
# Epoch 53/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9520 - loss: 0.1831 - val_accuracy: 0.9640 - val_loss: 0.1462
# Epoch 54/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9521 - loss: 0.1758 - val_accuracy: 0.9625 - val_loss: 0.1441
# Epoch 55/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9560 - loss: 0.1739 - val_accuracy: 0.9635 - val_loss: 0.1424
# Epoch 56/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9540 - loss: 0.1685 - val_accuracy: 0.9630 - val_loss: 0.1416
# Epoch 57/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9560 - loss: 0.1697 - val_accuracy: 0.9645 - val_loss: 0.1401
# Epoch 58/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9544 - loss: 0.1688 - val_accuracy: 0.9635 - val_loss: 0.1393
# Epoch 59/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9585 - loss: 0.1652 - val_accuracy: 0.9635 - val_loss: 0.1376
# Epoch 60/150
# 40/40 - 0s - 5ms/step - accuracy: 0.9569 - loss: 0.1611 - val_accuracy: 0.9640 - val_loss: 0.1367
# Epoch 61/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9607 - loss: 0.1589 - val_accuracy: 0.9635 - val_loss: 0.1357
# Epoch 62/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9586 - loss: 0.1575 - val_accuracy: 0.9640 - val_loss: 0.1358
# Epoch 63/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9609 - loss: 0.1558 - val_accuracy: 0.9655 - val_loss: 0.1341
# Epoch 64/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9621 - loss: 0.1531 - val_accuracy: 0.9655 - val_loss: 0.1331
# Epoch 65/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9600 - loss: 0.1544 - val_accuracy: 0.9645 - val_loss: 0.1325
# Epoch 66/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9616 - loss: 0.1510 - val_accuracy: 0.9650 - val_loss: 0.1310
# Epoch 67/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9605 - loss: 0.1532 - val_accuracy: 0.9630 - val_loss: 0.1301
# Epoch 68/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9619 - loss: 0.1528 - val_accuracy: 0.9655 - val_loss: 0.1280
# Epoch 69/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9631 - loss: 0.1466 - val_accuracy: 0.9645 - val_loss: 0.1280
# Epoch 70/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9620 - loss: 0.1481 - val_accuracy: 0.9665 - val_loss: 0.1263
# Epoch 71/150
# 40/40 - 1s - 23ms/step - accuracy: 0.9615 - loss: 0.1510 - val_accuracy: 0.9655 - val_loss: 0.1261
# Epoch 72/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9614 - loss: 0.1485 - val_accuracy: 0.9670 - val_loss: 0.1271
# Epoch 73/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9621 - loss: 0.1480 - val_accuracy: 0.9665 - val_loss: 0.1256
# Epoch 74/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9615 - loss: 0.1444 - val_accuracy: 0.9680 - val_loss: 0.1234
# Epoch 75/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9651 - loss: 0.1389 - val_accuracy: 0.9665 - val_loss: 0.1248
# Epoch 76/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9640 - loss: 0.1416 - val_accuracy: 0.9670 - val_loss: 0.1239
# Epoch 77/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9628 - loss: 0.1425 - val_accuracy: 0.9680 - val_loss: 0.1221
# Epoch 78/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9629 - loss: 0.1389 - val_accuracy: 0.9670 - val_loss: 0.1225
# Epoch 79/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9626 - loss: 0.1399 - val_accuracy: 0.9665 - val_loss: 0.1234
# Epoch 80/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9625 - loss: 0.1406 - val_accuracy: 0.9675 - val_loss: 0.1206
# Epoch 81/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9657 - loss: 0.1360 - val_accuracy: 0.9660 - val_loss: 0.1218
# Epoch 82/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9634 - loss: 0.1375 - val_accuracy: 0.9675 - val_loss: 0.1206
# Epoch 83/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9595 - loss: 0.1419 - val_accuracy: 0.9675 - val_loss: 0.1220
# Epoch 84/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9641 - loss: 0.1400 - val_accuracy: 0.9680 - val_loss: 0.1230
# Epoch 85/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9655 - loss: 0.1338 - val_accuracy: 0.9680 - val_loss: 0.1198
# Epoch 86/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9650 - loss: 0.1371 - val_accuracy: 0.9685 - val_loss: 0.1179
# Epoch 87/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9666 - loss: 0.1326 - val_accuracy: 0.9700 - val_loss: 0.1167
# Epoch 88/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9621 - loss: 0.1352 - val_accuracy: 0.9705 - val_loss: 0.1175
# Epoch 89/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9672 - loss: 0.1277 - val_accuracy: 0.9710 - val_loss: 0.1172
# Epoch 90/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9646 - loss: 0.1313 - val_accuracy: 0.9695 - val_loss: 0.1174
# Epoch 91/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9646 - loss: 0.1315 - val_accuracy: 0.9685 - val_loss: 0.1196
# Epoch 92/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9654 - loss: 0.1339 - val_accuracy: 0.9705 - val_loss: 0.1154
# Epoch 93/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9653 - loss: 0.1293 - val_accuracy: 0.9715 - val_loss: 0.1140
# Epoch 94/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9657 - loss: 0.1290 - val_accuracy: 0.9705 - val_loss: 0.1153
# Epoch 95/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9655 - loss: 0.1277 - val_accuracy: 0.9710 - val_loss: 0.1155
# Epoch 96/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9664 - loss: 0.1258 - val_accuracy: 0.9710 - val_loss: 0.1123
# Epoch 97/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9664 - loss: 0.1309 - val_accuracy: 0.9705 - val_loss: 0.1139
# Epoch 98/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9654 - loss: 0.1303 - val_accuracy: 0.9710 - val_loss: 0.1128
# Epoch 99/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9664 - loss: 0.1263 - val_accuracy: 0.9710 - val_loss: 0.1120
# Epoch 100/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9684 - loss: 0.1275 - val_accuracy: 0.9735 - val_loss: 0.1122
# Epoch 101/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9654 - loss: 0.1261 - val_accuracy: 0.9710 - val_loss: 0.1117
# Epoch 102/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9705 - loss: 0.1221 - val_accuracy: 0.9735 - val_loss: 0.1125
# Epoch 103/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9663 - loss: 0.1253 - val_accuracy: 0.9740 - val_loss: 0.1135
# Epoch 104/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9647 - loss: 0.1260 - val_accuracy: 0.9725 - val_loss: 0.1111
# Epoch 105/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9670 - loss: 0.1258 - val_accuracy: 0.9725 - val_loss: 0.1118
# Epoch 106/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9684 - loss: 0.1199 - val_accuracy: 0.9720 - val_loss: 0.1122
# Epoch 107/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9660 - loss: 0.1257 - val_accuracy: 0.9730 - val_loss: 0.1095
# Epoch 108/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9664 - loss: 0.1198 - val_accuracy: 0.9740 - val_loss: 0.1099
# Epoch 109/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9663 - loss: 0.1228 - val_accuracy: 0.9735 - val_loss: 0.1097
# Epoch 110/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9676 - loss: 0.1225 - val_accuracy: 0.9745 - val_loss: 0.1077
# Epoch 111/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9697 - loss: 0.1206 - val_accuracy: 0.9730 - val_loss: 0.1071
# Epoch 112/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9696 - loss: 0.1178 - val_accuracy: 0.9740 - val_loss: 0.1091
# Epoch 113/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9675 - loss: 0.1208 - val_accuracy: 0.9730 - val_loss: 0.1080
# Epoch 114/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9693 - loss: 0.1192 - val_accuracy: 0.9735 - val_loss: 0.1066
# Epoch 115/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9703 - loss: 0.1181 - val_accuracy: 0.9735 - val_loss: 0.1064
# Epoch 116/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9690 - loss: 0.1157 - val_accuracy: 0.9750 - val_loss: 0.1064
# Epoch 117/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9693 - loss: 0.1156 - val_accuracy: 0.9745 - val_loss: 0.1080
# Epoch 118/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9681 - loss: 0.1183 - val_accuracy: 0.9740 - val_loss: 0.1062
# Epoch 119/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9676 - loss: 0.1174 - val_accuracy: 0.9740 - val_loss: 0.1109
# Epoch 120/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9681 - loss: 0.1175 - val_accuracy: 0.9745 - val_loss: 0.1062
# Epoch 121/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9705 - loss: 0.1157 - val_accuracy: 0.9750 - val_loss: 0.1058
# Epoch 122/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9689 - loss: 0.1144 - val_accuracy: 0.9755 - val_loss: 0.1049
# Epoch 123/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9695 - loss: 0.1143 - val_accuracy: 0.9735 - val_loss: 0.1052
# Epoch 124/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9722 - loss: 0.1111 - val_accuracy: 0.9745 - val_loss: 0.1060
# Epoch 125/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9676 - loss: 0.1192 - val_accuracy: 0.9750 - val_loss: 0.1041
# Epoch 126/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9696 - loss: 0.1118 - val_accuracy: 0.9760 - val_loss: 0.1035
# Epoch 127/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9705 - loss: 0.1126 - val_accuracy: 0.9750 - val_loss: 0.1072
# Epoch 128/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9710 - loss: 0.1133 - val_accuracy: 0.9740 - val_loss: 0.1046
# Epoch 129/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9685 - loss: 0.1157 - val_accuracy: 0.9755 - val_loss: 0.1051
# Epoch 130/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9668 - loss: 0.1142 - val_accuracy: 0.9745 - val_loss: 0.1036
# Epoch 131/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9696 - loss: 0.1116 - val_accuracy: 0.9735 - val_loss: 0.1071
# Epoch 132/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9664 - loss: 0.1223 - val_accuracy: 0.9750 - val_loss: 0.1046
# Epoch 133/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9704 - loss: 0.1131 - val_accuracy: 0.9750 - val_loss: 0.1031
# Epoch 134/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9711 - loss: 0.1108 - val_accuracy: 0.9750 - val_loss: 0.1037
# Epoch 135/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9694 - loss: 0.1117 - val_accuracy: 0.9755 - val_loss: 0.1056
# Epoch 136/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9695 - loss: 0.1126 - val_accuracy: 0.9735 - val_loss: 0.1053
# Epoch 137/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9704 - loss: 0.1125 - val_accuracy: 0.9750 - val_loss: 0.1032
# Epoch 138/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9704 - loss: 0.1111 - val_accuracy: 0.9765 - val_loss: 0.1061
# Epoch 139/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9693 - loss: 0.1132 - val_accuracy: 0.9750 - val_loss: 0.1026
# Epoch 140/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9695 - loss: 0.1126 - val_accuracy: 0.9750 - val_loss: 0.1050
# Epoch 141/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9707 - loss: 0.1122 - val_accuracy: 0.9750 - val_loss: 0.1030
# Epoch 142/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9724 - loss: 0.1075 - val_accuracy: 0.9750 - val_loss: 0.1036
# Epoch 143/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9709 - loss: 0.1121 - val_accuracy: 0.9750 - val_loss: 0.1040
# Epoch 144/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9670 - loss: 0.1161 - val_accuracy: 0.9735 - val_loss: 0.1049
# Epoch 145/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9712 - loss: 0.1083 - val_accuracy: 0.9740 - val_loss: 0.1063
# Epoch 146/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9695 - loss: 0.1100 - val_accuracy: 0.9755 - val_loss: 0.1021
# Epoch 147/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9688 - loss: 0.1104 - val_accuracy: 0.9740 - val_loss: 0.1055
# Epoch 148/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9697 - loss: 0.1130 - val_accuracy: 0.9755 - val_loss: 0.1012
# Epoch 149/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9716 - loss: 0.1091 - val_accuracy: 0.9740 - val_loss: 0.1043
# Epoch 150/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9703 - loss: 0.1090 - val_accuracy: 0.9750 - val_loss: 0.1019

# %%
def Show_history(fit):
    fig,AX=plt.subplots(1,2,figsize=(12,5.))
    ax=AX[0] 
    ax.plot(fit.history['accuracy'],"b",label="train")
    ax.plot(fit.history['val_accuracy'],"r--",label="valid.")
    ax.plot((0,EPOCHS),(1/3,1/3),":",c="gray",label="random choice")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Accuracy")
    ax.set_ylim([0, 1])
    ax.legend()
    ax=AX[1]
    ax.plot(fit.history['loss'],"b",label="train")
    ax.plot(fit.history['val_loss'],"r--",label="valid.")
    ax.set_xlabel('epoch')
    ax.set_ylabel("Loss")
    ax.set_ylim([0, 1.05*np.max(fit.history['loss'])])
    ax.legend()
    plt.show()
Show_history(fit)
Show_weights(model,0)
Show_weights(model,2)
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# ...LESSON ...
reg2 = tf.keras.regularizers.l1(0.5)
model2 = keras.models.clone_model(model)
model2.layers[0].kernel_regularizer = reg2
model2.layers[2].kernel_regularizer = reg2
opt2 = tf.keras.optimizers.Adam()   # NEW optimizer instance
model2.compile(loss=keras.losses.categorical_crossentropy,optimizer=opt2,metrics=['accuracy'])

BATCH_SIZE2 = 200
EPOCHS2 = 150

fit2 = model2.fit(x_train,y_train,batch_size=BATCH_SIZE2,epochs=EPOCHS2,
                validation_data=(x_val, y_val), verbose=2, shuffle=True)
# Out:
# Epoch 1/150
# 40/40 - 1s - 26ms/step - accuracy: 0.3815 - loss: 1.1116 - val_accuracy: 0.4525 - val_loss: 1.0966
# Epoch 2/150
# 40/40 - 1s - 19ms/step - accuracy: 0.4467 - loss: 1.0825 - val_accuracy: 0.4890 - val_loss: 1.0693
# Epoch 3/150
# 40/40 - 0s - 11ms/step - accuracy: 0.5114 - loss: 1.0409 - val_accuracy: 0.5710 - val_loss: 1.0011
# Epoch 4/150
# 40/40 - 1s - 20ms/step - accuracy: 0.5799 - loss: 0.9401 - val_accuracy: 0.6665 - val_loss: 0.8549
# Epoch 5/150
# 40/40 - 1s - 24ms/step - accuracy: 0.6481 - loss: 0.8105 - val_accuracy: 0.7510 - val_loss: 0.7288
# Epoch 6/150
# 40/40 - 1s - 20ms/step - accuracy: 0.7024 - loss: 0.7284 - val_accuracy: 0.7945 - val_loss: 0.6529
# Epoch 7/150
# 40/40 - 1s - 17ms/step - accuracy: 0.7437 - loss: 0.6640 - val_accuracy: 0.8190 - val_loss: 0.5931
# Epoch 8/150
# 40/40 - 0s - 12ms/step - accuracy: 0.7709 - loss: 0.6173 - val_accuracy: 0.8455 - val_loss: 0.5479
# Epoch 9/150
# 40/40 - 1s - 19ms/step - accuracy: 0.7931 - loss: 0.5711 - val_accuracy: 0.8560 - val_loss: 0.5073
# Epoch 10/150
# 40/40 - 1s - 15ms/step - accuracy: 0.8100 - loss: 0.5387 - val_accuracy: 0.8640 - val_loss: 0.4740
# Epoch 11/150
# 40/40 - 0s - 10ms/step - accuracy: 0.8257 - loss: 0.5069 - val_accuracy: 0.8755 - val_loss: 0.4411
# Epoch 12/150
# 40/40 - 1s - 22ms/step - accuracy: 0.8476 - loss: 0.4654 - val_accuracy: 0.8940 - val_loss: 0.3990
# Epoch 13/150
# 40/40 - 1s - 20ms/step - accuracy: 0.8645 - loss: 0.4252 - val_accuracy: 0.9010 - val_loss: 0.3593
# Epoch 14/150
# 40/40 - 0s - 7ms/step - accuracy: 0.8817 - loss: 0.3915 - val_accuracy: 0.9110 - val_loss: 0.3255
# Epoch 15/150
# 40/40 - 1s - 19ms/step - accuracy: 0.8953 - loss: 0.3554 - val_accuracy: 0.9170 - val_loss: 0.2988
# Epoch 16/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9029 - loss: 0.3332 - val_accuracy: 0.9240 - val_loss: 0.2780
# Epoch 17/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9109 - loss: 0.3132 - val_accuracy: 0.9300 - val_loss: 0.2614
# Epoch 18/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9208 - loss: 0.2917 - val_accuracy: 0.9330 - val_loss: 0.2487
# Epoch 19/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9190 - loss: 0.2807 - val_accuracy: 0.9365 - val_loss: 0.2405
# Epoch 20/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9268 - loss: 0.2657 - val_accuracy: 0.9405 - val_loss: 0.2299
# Epoch 21/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9337 - loss: 0.2549 - val_accuracy: 0.9410 - val_loss: 0.2243
# Epoch 22/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9329 - loss: 0.2473 - val_accuracy: 0.9445 - val_loss: 0.2151
# Epoch 23/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9337 - loss: 0.2419 - val_accuracy: 0.9490 - val_loss: 0.2097
# Epoch 24/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9367 - loss: 0.2351 - val_accuracy: 0.9500 - val_loss: 0.2075
# Epoch 25/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9439 - loss: 0.2294 - val_accuracy: 0.9490 - val_loss: 0.2000
# Epoch 26/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9392 - loss: 0.2232 - val_accuracy: 0.9520 - val_loss: 0.1950
# Epoch 27/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9420 - loss: 0.2185 - val_accuracy: 0.9525 - val_loss: 0.1922
# Epoch 28/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9477 - loss: 0.2072 - val_accuracy: 0.9545 - val_loss: 0.1894
# Epoch 29/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9444 - loss: 0.2140 - val_accuracy: 0.9545 - val_loss: 0.1866
# Epoch 30/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9479 - loss: 0.2041 - val_accuracy: 0.9540 - val_loss: 0.1833
# Epoch 31/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9524 - loss: 0.2007 - val_accuracy: 0.9575 - val_loss: 0.1816
# Epoch 32/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9509 - loss: 0.1971 - val_accuracy: 0.9555 - val_loss: 0.1780
# Epoch 33/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9513 - loss: 0.1978 - val_accuracy: 0.9560 - val_loss: 0.1765
# Epoch 34/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9514 - loss: 0.1934 - val_accuracy: 0.9555 - val_loss: 0.1736
# Epoch 35/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9536 - loss: 0.1906 - val_accuracy: 0.9585 - val_loss: 0.1713
# Epoch 36/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9555 - loss: 0.1848 - val_accuracy: 0.9570 - val_loss: 0.1709
# Epoch 37/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9505 - loss: 0.1878 - val_accuracy: 0.9575 - val_loss: 0.1689
# Epoch 38/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9544 - loss: 0.1852 - val_accuracy: 0.9580 - val_loss: 0.1679
# Epoch 39/150
# 40/40 - 1s - 24ms/step - accuracy: 0.9509 - loss: 0.1807 - val_accuracy: 0.9585 - val_loss: 0.1659
# Epoch 40/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9574 - loss: 0.1786 - val_accuracy: 0.9565 - val_loss: 0.1657
# Epoch 41/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9534 - loss: 0.1785 - val_accuracy: 0.9585 - val_loss: 0.1632
# Epoch 42/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9563 - loss: 0.1767 - val_accuracy: 0.9590 - val_loss: 0.1624
# Epoch 43/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9579 - loss: 0.1728 - val_accuracy: 0.9590 - val_loss: 0.1588
# Epoch 44/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9576 - loss: 0.1681 - val_accuracy: 0.9605 - val_loss: 0.1556
# Epoch 45/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9588 - loss: 0.1686 - val_accuracy: 0.9600 - val_loss: 0.1552
# Epoch 46/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9594 - loss: 0.1660 - val_accuracy: 0.9605 - val_loss: 0.1529
# Epoch 47/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9599 - loss: 0.1661 - val_accuracy: 0.9620 - val_loss: 0.1531
# Epoch 48/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9586 - loss: 0.1654 - val_accuracy: 0.9615 - val_loss: 0.1524
# Epoch 49/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9586 - loss: 0.1658 - val_accuracy: 0.9610 - val_loss: 0.1520
# Epoch 50/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9557 - loss: 0.1649 - val_accuracy: 0.9615 - val_loss: 0.1516
# Epoch 51/150
# 40/40 - 0s - 5ms/step - accuracy: 0.9599 - loss: 0.1641 - val_accuracy: 0.9610 - val_loss: 0.1482
# Epoch 52/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9610 - loss: 0.1599 - val_accuracy: 0.9620 - val_loss: 0.1473
# Epoch 53/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9622 - loss: 0.1555 - val_accuracy: 0.9630 - val_loss: 0.1451
# Epoch 54/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9603 - loss: 0.1603 - val_accuracy: 0.9625 - val_loss: 0.1463
# Epoch 55/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9635 - loss: 0.1516 - val_accuracy: 0.9640 - val_loss: 0.1429
# Epoch 56/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9610 - loss: 0.1565 - val_accuracy: 0.9645 - val_loss: 0.1434
# Epoch 57/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9615 - loss: 0.1516 - val_accuracy: 0.9645 - val_loss: 0.1452
# Epoch 58/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9606 - loss: 0.1549 - val_accuracy: 0.9635 - val_loss: 0.1436
# Epoch 59/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9655 - loss: 0.1504 - val_accuracy: 0.9645 - val_loss: 0.1425
# Epoch 60/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9621 - loss: 0.1486 - val_accuracy: 0.9665 - val_loss: 0.1378
# Epoch 61/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9643 - loss: 0.1445 - val_accuracy: 0.9675 - val_loss: 0.1375
# Epoch 62/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9655 - loss: 0.1416 - val_accuracy: 0.9660 - val_loss: 0.1374
# Epoch 63/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9600 - loss: 0.1463 - val_accuracy: 0.9640 - val_loss: 0.1383
# Epoch 64/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9634 - loss: 0.1464 - val_accuracy: 0.9645 - val_loss: 0.1390
# Epoch 65/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9651 - loss: 0.1408 - val_accuracy: 0.9640 - val_loss: 0.1378
# Epoch 66/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9657 - loss: 0.1413 - val_accuracy: 0.9655 - val_loss: 0.1367
# Epoch 67/150
# 40/40 - 1s - 25ms/step - accuracy: 0.9614 - loss: 0.1473 - val_accuracy: 0.9640 - val_loss: 0.1379
# Epoch 68/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9651 - loss: 0.1421 - val_accuracy: 0.9675 - val_loss: 0.1335
# Epoch 69/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9651 - loss: 0.1405 - val_accuracy: 0.9690 - val_loss: 0.1322
# Epoch 70/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9668 - loss: 0.1383 - val_accuracy: 0.9660 - val_loss: 0.1327
# Epoch 71/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9645 - loss: 0.1425 - val_accuracy: 0.9655 - val_loss: 0.1336
# Epoch 72/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9657 - loss: 0.1413 - val_accuracy: 0.9670 - val_loss: 0.1313
# Epoch 73/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9656 - loss: 0.1378 - val_accuracy: 0.9660 - val_loss: 0.1306
# Epoch 74/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9660 - loss: 0.1360 - val_accuracy: 0.9675 - val_loss: 0.1297
# Epoch 75/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9644 - loss: 0.1361 - val_accuracy: 0.9670 - val_loss: 0.1323
# Epoch 76/150
# 40/40 - 0s - 10ms/step - accuracy: 0.9665 - loss: 0.1360 - val_accuracy: 0.9660 - val_loss: 0.1317
# Epoch 77/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9672 - loss: 0.1323 - val_accuracy: 0.9670 - val_loss: 0.1279
# Epoch 78/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9649 - loss: 0.1333 - val_accuracy: 0.9685 - val_loss: 0.1274
# Epoch 79/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9656 - loss: 0.1350 - val_accuracy: 0.9660 - val_loss: 0.1268
# Epoch 80/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9684 - loss: 0.1305 - val_accuracy: 0.9675 - val_loss: 0.1267
# Epoch 81/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9686 - loss: 0.1276 - val_accuracy: 0.9680 - val_loss: 0.1277
# Epoch 82/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9660 - loss: 0.1314 - val_accuracy: 0.9660 - val_loss: 0.1270
# Epoch 83/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9679 - loss: 0.1282 - val_accuracy: 0.9710 - val_loss: 0.1220
# Epoch 84/150
# 40/40 - 0s - 5ms/step - accuracy: 0.9646 - loss: 0.1288 - val_accuracy: 0.9665 - val_loss: 0.1234
# Epoch 85/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9666 - loss: 0.1293 - val_accuracy: 0.9675 - val_loss: 0.1250
# Epoch 86/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9714 - loss: 0.1200 - val_accuracy: 0.9670 - val_loss: 0.1228
# Epoch 87/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9694 - loss: 0.1242 - val_accuracy: 0.9690 - val_loss: 0.1227
# Epoch 88/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9688 - loss: 0.1250 - val_accuracy: 0.9675 - val_loss: 0.1250
# Epoch 89/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9697 - loss: 0.1260 - val_accuracy: 0.9650 - val_loss: 0.1249
# Epoch 90/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9691 - loss: 0.1245 - val_accuracy: 0.9665 - val_loss: 0.1229
# Epoch 91/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9660 - loss: 0.1298 - val_accuracy: 0.9680 - val_loss: 0.1218
# Epoch 92/150
# 40/40 - 1s - 23ms/step - accuracy: 0.9691 - loss: 0.1222 - val_accuracy: 0.9690 - val_loss: 0.1209
# Epoch 93/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9690 - loss: 0.1238 - val_accuracy: 0.9640 - val_loss: 0.1264
# Epoch 94/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9697 - loss: 0.1219 - val_accuracy: 0.9670 - val_loss: 0.1208
# Epoch 95/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9696 - loss: 0.1197 - val_accuracy: 0.9655 - val_loss: 0.1212
# Epoch 96/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9700 - loss: 0.1180 - val_accuracy: 0.9700 - val_loss: 0.1175
# Epoch 97/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9704 - loss: 0.1199 - val_accuracy: 0.9670 - val_loss: 0.1177
# Epoch 98/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9695 - loss: 0.1198 - val_accuracy: 0.9670 - val_loss: 0.1182
# Epoch 99/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9691 - loss: 0.1206 - val_accuracy: 0.9685 - val_loss: 0.1160
# Epoch 100/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9719 - loss: 0.1192 - val_accuracy: 0.9675 - val_loss: 0.1176
# Epoch 101/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9682 - loss: 0.1197 - val_accuracy: 0.9680 - val_loss: 0.1171
# Epoch 102/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9697 - loss: 0.1201 - val_accuracy: 0.9675 - val_loss: 0.1184
# Epoch 103/150
# 40/40 - 0s - 7ms/step - accuracy: 0.9685 - loss: 0.1207 - val_accuracy: 0.9685 - val_loss: 0.1187
# Epoch 104/150
# 40/40 - 1s - 22ms/step - accuracy: 0.9695 - loss: 0.1158 - val_accuracy: 0.9675 - val_loss: 0.1173
# Epoch 105/150
# 40/40 - 1s - 23ms/step - accuracy: 0.9704 - loss: 0.1173 - val_accuracy: 0.9690 - val_loss: 0.1160
# Epoch 106/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9710 - loss: 0.1112 - val_accuracy: 0.9700 - val_loss: 0.1135
# Epoch 107/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9704 - loss: 0.1138 - val_accuracy: 0.9675 - val_loss: 0.1160
# Epoch 108/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9718 - loss: 0.1118 - val_accuracy: 0.9695 - val_loss: 0.1136
# Epoch 109/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9712 - loss: 0.1115 - val_accuracy: 0.9690 - val_loss: 0.1117
# Epoch 110/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9732 - loss: 0.1131 - val_accuracy: 0.9670 - val_loss: 0.1152
# Epoch 111/150
# 40/40 - 0s - 5ms/step - accuracy: 0.9719 - loss: 0.1127 - val_accuracy: 0.9690 - val_loss: 0.1115
# Epoch 112/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9714 - loss: 0.1109 - val_accuracy: 0.9705 - val_loss: 0.1095
# Epoch 113/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9716 - loss: 0.1138 - val_accuracy: 0.9690 - val_loss: 0.1112
# Epoch 114/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9710 - loss: 0.1125 - val_accuracy: 0.9695 - val_loss: 0.1102
# Epoch 115/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9729 - loss: 0.1080 - val_accuracy: 0.9715 - val_loss: 0.1081
# Epoch 116/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9725 - loss: 0.1079 - val_accuracy: 0.9680 - val_loss: 0.1086
# Epoch 117/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9714 - loss: 0.1110 - val_accuracy: 0.9685 - val_loss: 0.1108
# Epoch 118/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9691 - loss: 0.1105 - val_accuracy: 0.9715 - val_loss: 0.1078
# Epoch 119/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9721 - loss: 0.1051 - val_accuracy: 0.9700 - val_loss: 0.1066
# Epoch 120/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9712 - loss: 0.1077 - val_accuracy: 0.9710 - val_loss: 0.1053
# Epoch 121/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9741 - loss: 0.1059 - val_accuracy: 0.9700 - val_loss: 0.1084
# Epoch 122/150
# 40/40 - 0s - 11ms/step - accuracy: 0.9759 - loss: 0.1035 - val_accuracy: 0.9725 - val_loss: 0.1037
# Epoch 123/150
# 40/40 - 1s - 19ms/step - accuracy: 0.9737 - loss: 0.1022 - val_accuracy: 0.9715 - val_loss: 0.1033
# Epoch 124/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9751 - loss: 0.1038 - val_accuracy: 0.9730 - val_loss: 0.1033
# Epoch 125/150
# 40/40 - 0s - 3ms/step - accuracy: 0.9737 - loss: 0.1014 - val_accuracy: 0.9735 - val_loss: 0.1007
# Epoch 126/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9746 - loss: 0.1005 - val_accuracy: 0.9740 - val_loss: 0.0997
# Epoch 127/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9728 - loss: 0.1055 - val_accuracy: 0.9730 - val_loss: 0.1018
# Epoch 128/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9746 - loss: 0.0997 - val_accuracy: 0.9740 - val_loss: 0.1004
# Epoch 129/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9734 - loss: 0.1007 - val_accuracy: 0.9735 - val_loss: 0.1014
# Epoch 130/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9766 - loss: 0.0969 - val_accuracy: 0.9690 - val_loss: 0.1032
# Epoch 131/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9770 - loss: 0.0975 - val_accuracy: 0.9750 - val_loss: 0.0989
# Epoch 132/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9759 - loss: 0.0965 - val_accuracy: 0.9760 - val_loss: 0.0973
# Epoch 133/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9750 - loss: 0.0977 - val_accuracy: 0.9750 - val_loss: 0.0992
# Epoch 134/150
# 40/40 - 1s - 21ms/step - accuracy: 0.9747 - loss: 0.1004 - val_accuracy: 0.9740 - val_loss: 0.0996
# Epoch 135/150
# 40/40 - 1s - 13ms/step - accuracy: 0.9768 - loss: 0.0954 - val_accuracy: 0.9765 - val_loss: 0.0952
# Epoch 136/150
# 40/40 - 1s - 20ms/step - accuracy: 0.9774 - loss: 0.0935 - val_accuracy: 0.9755 - val_loss: 0.0956
# Epoch 137/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9779 - loss: 0.0931 - val_accuracy: 0.9740 - val_loss: 0.0962
# Epoch 138/150
# 40/40 - 0s - 6ms/step - accuracy: 0.9774 - loss: 0.0924 - val_accuracy: 0.9755 - val_loss: 0.0944
# Epoch 139/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9780 - loss: 0.0934 - val_accuracy: 0.9750 - val_loss: 0.0959
# Epoch 140/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9770 - loss: 0.0925 - val_accuracy: 0.9750 - val_loss: 0.0961
# Epoch 141/150
# 40/40 - 1s - 17ms/step - accuracy: 0.9771 - loss: 0.0907 - val_accuracy: 0.9755 - val_loss: 0.0960
# Epoch 142/150
# 40/40 - 0s - 12ms/step - accuracy: 0.9778 - loss: 0.0925 - val_accuracy: 0.9750 - val_loss: 0.0927
# Epoch 143/150
# 40/40 - 1s - 18ms/step - accuracy: 0.9774 - loss: 0.0933 - val_accuracy: 0.9765 - val_loss: 0.0915
# Epoch 144/150
# 40/40 - 0s - 9ms/step - accuracy: 0.9789 - loss: 0.0889 - val_accuracy: 0.9755 - val_loss: 0.0923
# Epoch 145/150
# 40/40 - 0s - 4ms/step - accuracy: 0.9789 - loss: 0.0887 - val_accuracy: 0.9745 - val_loss: 0.0926
# Epoch 146/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9785 - loss: 0.0890 - val_accuracy: 0.9755 - val_loss: 0.0913
# Epoch 147/150
# 40/40 - 1s - 14ms/step - accuracy: 0.9779 - loss: 0.0909 - val_accuracy: 0.9770 - val_loss: 0.0890
# Epoch 148/150
# 40/40 - 1s - 16ms/step - accuracy: 0.9778 - loss: 0.0878 - val_accuracy: 0.9770 - val_loss: 0.0904
# Epoch 149/150
# 40/40 - 1s - 15ms/step - accuracy: 0.9770 - loss: 0.0894 - val_accuracy: 0.9770 - val_loss: 0.0904
# Epoch 150/150
# 40/40 - 0s - 8ms/step - accuracy: 0.9795 - loss: 0.0862 - val_accuracy: 0.9755 - val_loss: 0.0885

# %%
Show_history(fit)
Show_history(fit2)
Show_weights(model2,0,label="model2")
Show_weights(model2,2,label="model2")
# Out:
# (11, 1, 5)
# (5, 1, 11)
# (7, 5, 5)
# (5, 5, 7)

# %%
# confusion table: compare true labels with predicted ones
import pandas as pd
from scipy import stats

import seaborn 
from sklearn import metrics

from sklearn.metrics import classification_report
from sklearn import preprocessing

LABELS = ["absent","positive","negative"] # from labels y 
cmap="GnBu"

def show_confusion_matrix(validations, predictions, label="Model"):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(6, 5))
    seaborn.heatmap(matrix,
                xticklabels=LABELS,
                yticklabels=LABELS,
                annot=True,
                fmt='d',
                linecolor='white',
                linewidths=1,
                cmap=cmap)
    plt.title(label+': Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

y_pred_val = model.predict(x_val)
y_pred_val2 = model2.predict(x_val)
# Take the class with the highest probability from the val predictions
max_y_pred_val = np.argmax(y_pred_val, axis=1)
max_y_val = np.argmax(y_val, axis=1)
max_y_pred_val2 = np.argmax(y_pred_val2, axis=1)

show_confusion_matrix(max_y_val, max_y_pred_val)
show_confusion_matrix(max_y_val, max_y_pred_val2, label="Model 2")

#print(classification_report(max_y_val, max_y_pred_val))
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
